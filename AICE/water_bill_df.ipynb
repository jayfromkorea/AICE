# %%
import pandas as pd
import os
print(os.listdir())
os.chdir(r'C:\Users\User\Documents\python_lesson_lecturer\aice\AICE')
print(os.path.exists('data'))
# Out:
# ['AICE', 'water_bill_df.ipynb']
# True

# %%
df1 = pd.read_csv('data/water_bill.csv', encoding='cp949')
df2 = pd.read_csv('data/flight.csv')
df1.head(3)
# Out:
#         수용가번호 읍면동명   업종  사용량    사용요금       납기마감일
# 0  1001020000  중구동  일반용   14   13310  2025-11-24
# 1  1001030000  중구동  일반용    2    1900  2025-11-24
# 2  1001040000  중구동  일반용  152  315890  2025-11-24
